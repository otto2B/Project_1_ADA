# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print('hello copy git ')
# Out:
# hello

# %%
data = pd.read_csv("/content/OpenFoodFacts.csv", sep = '\t')
# Out:
# /Users/clementgrillet/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,24,25,26,28,44,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#                          code  \
# 0               0000000000017
# 1               0000000000031
# 2        00000000001111111111
# 3               0000000000123
# 4               0000000000178
# ...                       ...
# 1013896              99999971
# 1013897              99999988
# 1013898         9999999004360
# 1013899              99999995
# 1013900         9999999900686
#
#                                                        url  \
# 0        http://world-en.openfoodfacts.org/product/0000...
# 1        http://world-en.openfoodfacts.org/product/0000...
# 2        http://world-en.openfoodfacts.org/product/0000...
# 3        http://world-en.openfoodfacts.org/product/0000...
# 4        http://world-en.openfoodfacts.org/product/0000...
# ...                                                    ...
# 1013896  http://world-en.openfoodfacts.org/product/9999...
# 1013897  http://world-en.openfoodfacts.org/product/9999...
# ...

# %%
data.drop(["code",'url','creator','created_t','created_datetime','last_modified_t','last_modified_datetime',\
          'packaging', 'brands_tags','categories','categories_en','origins'], axis = 1)
# Out:
#                   product_name             generic_name quantity  \
# 0             Vitória crackers                      NaN      NaN
# 1                        Cacao                      NaN    130 g
# 2                      Sfiudwx                      NaN    dgesc
# 3        Sauce Sweety chili 0%                      NaN      NaN
# 4                    Mini coco                      NaN      NaN
# ...                        ...                      ...      ...
# 1013896                   test                      NaN      NaN
# 1013897                 Boules                      NaN      NaN
# 1013898         Minis beignets  Beignets natures sucrés      NaN
# 1013899  Steak haché pur boeuf                      NaN      NaN
# 1013900         Marrons glacés                      NaN      NaN
#
#         packaging_tags brands  \
# 0                  NaN    NaN
# 1                  NaN    NaN
# 2                  NaN   Watt
# 3                  NaN    NaN
# ...
